# %% [markdown]
# #Pandas Mastery Notebook
# Author:Amol Tulshidas Jagtap
# Goal:Learn pandas for data analysis and AI ML foundations

# %%
#Import pandas and giving alias name
import pandas as pd

# %% [markdown]
# ##SERIES
# A Series is a one-dimensional labaled array in pandas.

# %%
s = pd.Series([10, 20, 30, 40, 50])
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
#Access element
s[0]
# Out:
# np.int64(10)

# %%
#Basic operations
